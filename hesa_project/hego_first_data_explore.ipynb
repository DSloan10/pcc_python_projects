# %% [markdown]
# # Higher Education Graduate Outcomes: First Data explore

# %%
import pandas as pd
import numpy as np

# %%
characteristic_data = pd.read_csv("hego_data/hego_17_18_salary_by_characteristic.csv", skiprows = 13)
institution_data = pd.read_csv("hego_data/hego_17_18_salary_by_institution.csv", skiprows = 13)
subject_data = pd.read_csv("hego_data/hego_17_18_salary_by_subject.csv", skiprows = 13)

# %%
characteristic_data
# Out:
#        Personal characteristic category filter  \
# 0                                          Sex
# 1                                          Sex
# 2                                          Sex
# 3                                          Sex
# 4                                          Sex
# ...                                        ...
# 137705                                   Total
# 137706                                   Total
# 137707                                   Total
# 137708                                   Total
# 137709                                   Total
#
#        Personal characteristic category Country of provider  \
# 0                                Female             England
# 1                                Female             England
# 2                                Female             England
# 3                                Female             England
# 4                                Female             England
# ...

# %%
institution_data
# Out:
#              UKPRN              Provider name Country of provider  \
# 0       10008071.0  AA School of Architecture             England
# 1       10008071.0  AA School of Architecture             England
# 2       10008071.0  AA School of Architecture             England
# 3       10008071.0  AA School of Architecture             England
# 4       10008071.0  AA School of Architecture             England
# ...            ...                        ...                 ...
# 113875         NaN                      Total               Wales
# 113876         NaN                      Total               Wales
# 113877         NaN                      Total               Wales
# 113878         NaN                      Total               Wales
# 113879         NaN                      Total               Wales
#
#        Mode of former study     Skill group  \
# 0                 Full-time    High skilled
# 1                 Full-time    High skilled
# ...

# %%
subject_data
# Out:
#           Subject area of degree Country of provider  \
# 0       (1) Medicine & dentistry             England
# 1       (1) Medicine & dentistry             England
# 2       (1) Medicine & dentistry             England
# 3       (1) Medicine & dentistry             England
# 4       (1) Medicine & dentistry             England
# ...                          ...                 ...
# 367965                     Total               Wales
# 367966                     Total               Wales
# 367967                     Total               Wales
# 367968                     Total               Wales
# 367969                     Total               Wales
#
#                             Provider type Level of qualification  \
# 0       Further education colleges (FECs)                    All
# 1       Further education colleges (FECs)                    All
# 2       Further education colleges (FECs)                    All
# ...

# %%
characteristic_data.shape

institution_data.shape

subject_data.shape
# Out:
# (367970, 9)

# %%
characteristic_data.describe(include = "all")
# Out:
#        Personal characteristic category filter  \
# count                                   137710
# unique                                       5
# top                                  Ethnicity
# freq                                     49380
# mean                                       NaN
# std                                        NaN
# min                                        NaN
# 25%                                        NaN
# 50%                                        NaN
# 75%                                        NaN
# max                                        NaN
#
#        Personal characteristic category Country of provider Provider type  \
# count                            137710              137710        137710
# unique                               18                   5             3
# top                 No known disability                 All           All
# freq                               9680               33160         53640
# ...

# %%
institution_data.describe(include = "all")
# Out:
#                UKPRN Provider name Country of provider Mode of former study  \
# count   1.126800e+05        113880              113880               113880
# unique           NaN           316                   5                    3
# top              NaN         Total                 All                  All
# freq             NaN          1200               56340                46040
# mean    1.000774e+07           NaN                 NaN                  NaN
# std     8.384272e+03           NaN                 NaN                  NaN
# min     1.000009e+07           NaN                 NaN                  NaN
# 25%     1.000396e+07           NaN                 NaN                  NaN
# 50%     1.000714e+07           NaN                 NaN                  NaN
# 75%     1.000780e+07           NaN                 NaN                  NaN
# max     1.006655e+07           NaN                 NaN                  NaN
#
# ...

# %%
subject_data.describe(include = "all")
# Out:
#        Subject area of degree Country of provider Provider type  \
# count                  367970              367970        367970
# unique                     23                   5             3
# top                     Total                 All           All
# freq                    22120               93590        157560
# mean                      NaN                 NaN           NaN
# std                       NaN                 NaN           NaN
# min                       NaN                 NaN           NaN
# 25%                       NaN                 NaN           NaN
# 50%                       NaN                 NaN           NaN
# 75%                       NaN                 NaN           NaN
# max                       NaN                 NaN           NaN
#
#        Level of qualification Mode of former study Skill group  \
# count                  367970               367970      367970
# unique                      8                    3           4
# ...

# %% [markdown]
# None of the above really seem to refer to anything, but just thought i'd incude them for now for practice.

# %%
characteristic_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 137710 entries, 0 to 137709
# Data columns (total 10 columns):
#  #   Column                                   Non-Null Count   Dtype
# ---  ------                                   --------------   -----
#  0   Personal characteristic category filter  137710 non-null  object
#  1   Personal characteristic category         137710 non-null  object
#  2   Country of provider                      137710 non-null  object
#  3   Provider type                            137710 non-null  object
#  4   Level of qualification                   137710 non-null  object
#  5   Mode of former study                     137710 non-null  object
#  6   Skill group                              137710 non-null  object
#  7   Work population marker                   137710 non-null  object
#  8   Salary band                              137710 non-null  object
#  9   Number                                   137710 non-null  int64
# ...

# %%
institution_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 113880 entries, 0 to 113879
# Data columns (total 8 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   UKPRN                   112680 non-null  float64
#  1   Provider name           113880 non-null  object
#  2   Country of provider     113880 non-null  object
#  3   Mode of former study    113880 non-null  object
#  4   Skill group             113880 non-null  object
#  5   Work population marker  113880 non-null  object
#  6   Salary band             113880 non-null  object
#  7   Number                  113880 non-null  int64
# dtypes: float64(1), int64(1), object(6)
# memory usage: 7.0+ MB

# %%
subject_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 367970 entries, 0 to 367969
# Data columns (total 9 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   Subject area of degree  367970 non-null  object
#  1   Country of provider     367970 non-null  object
#  2   Provider type           367970 non-null  object
#  3   Level of qualification  367970 non-null  object
#  4   Mode of former study    367970 non-null  object
#  5   Skill group             367970 non-null  object
#  6   Work population marker  367970 non-null  object
#  7   Salary band             367970 non-null  object
#  8   Number                  367970 non-null  int64
# dtypes: int64(1), object(8)
# memory usage: 25.3+ MB

# %% [markdown]
# # Early ideas

# %% [markdown]
# Use these three datasets to create specific insights for the University of Dundee. These insights could, for example, include:
#
# 1. A breakdown of which subjects provide particularly high salaries for graudates and which provide lower. Take general results from across the UK and then use subject-ranking data to isolate areas where UoD is currently well-placed to create graduates that recieve higher pay once they enter the labour market.
#
# 2. An examination of which characteristic groups are less likely to enter higher paid work on average. Suggestions on how such individuals can be supported to a greater degree upon graduation.
#
# 3. A comparison of where the university ranks in comparison to other institutions in terms of salary output. Think about creating different categories for example Russell Group, Scottish Universities, Comparison to Welsh Universities, full devolved nation's comparisons.
#
# Other thoughts:
#
# Weighting of some sorts could come into this.
#
# Have a read of some more UoD strategy documentation to establish what current priorities look like and how insights could fit or be adapted to fit around these priorities.
#
# Start small and build up.

# %% [markdown]
# # Bit more practice with the data before analysis attempt

# %%
institution_data[["Country of provider", "Provider name"]]
# Out:
#        Country of provider              Provider name
# 0                  England  AA School of Architecture
# 1                  England  AA School of Architecture
# 2                  England  AA School of Architecture
# 3                  England  AA School of Architecture
# 4                  England  AA School of Architecture
# ...                    ...                        ...
# 113875               Wales                      Total
# 113876               Wales                      Total
# 113877               Wales                      Total
# 113878               Wales                      Total
# 113879               Wales                      Total
#
# [113880 rows x 2 columns]

# %%
institution_data[["Country of provider", "Provider name"]][1:10]
# Out:
#   Country of provider              Provider name
# 1             England  AA School of Architecture
# 2             England  AA School of Architecture
# 3             England  AA School of Architecture
# 4             England  AA School of Architecture
# 5             England  AA School of Architecture
# 6             England  AA School of Architecture
# 7             England  AA School of Architecture
# 8             England  AA School of Architecture
# 9             England  AA School of Architecture

# %%
institution_data.loc[[1, 2], "Country of provider"]
# Out:
# 1    England
# 2    England
# Name: Country of provider, dtype: object

# %%
institution_data_copy = institution_data.copy()

# %%
institution_data_copy.loc[institution_data_copy["Provider name"] == "The University of Dundee"]
# Out:
#             UKPRN             Provider name Country of provider  \
# 31200  10007852.0  The University of Dundee            Scotland
# 31201  10007852.0  The University of Dundee            Scotland
# 31202  10007852.0  The University of Dundee            Scotland
# 31203  10007852.0  The University of Dundee            Scotland
# 31204  10007852.0  The University of Dundee            Scotland
# ...           ...                       ...                 ...
# 31635  10007852.0  The University of Dundee            Scotland
# 31636  10007852.0  The University of Dundee            Scotland
# 31637  10007852.0  The University of Dundee            Scotland
# 31638  10007852.0  The University of Dundee            Scotland
# 31639  10007852.0  The University of Dundee            Scotland
#
#       Mode of former study   Skill group  \
# 31200            Full-time  High skilled
# 31201            Full-time  High skilled
# 31202            Full-time  High skilled
# ...

# %%
institution_data_copy.loc[(institution_data_copy["Provider name"] == "The University of Dundee") & (institution_data_copy["Mode of former study"] == "Full-time")]
# Out:
#             UKPRN             Provider name Country of provider  \
# 31200  10007852.0  The University of Dundee            Scotland
# 31201  10007852.0  The University of Dundee            Scotland
# 31202  10007852.0  The University of Dundee            Scotland
# 31203  10007852.0  The University of Dundee            Scotland
# 31204  10007852.0  The University of Dundee            Scotland
# ...           ...                       ...                 ...
# 31615  10007852.0  The University of Dundee            Scotland
# 31616  10007852.0  The University of Dundee            Scotland
# 31617  10007852.0  The University of Dundee            Scotland
# 31618  10007852.0  The University of Dundee            Scotland
# 31619  10007852.0  The University of Dundee            Scotland
#
#       Mode of former study   Skill group  \
# 31200            Full-time  High skilled
# 31201            Full-time  High skilled
# 31202            Full-time  High skilled
# ...

# %%
institution_data_copy.loc[(institution_data_copy
                           ["Provider name"] == "The University of Dundee"
                          ) 
                          & (institution_data_copy
                            ["Work population marker"].isin(["Paid employment is an activity", "Paid employment is most important activity"]))]
# Out:
#             UKPRN             Provider name Country of provider  \
# 31200  10007852.0  The University of Dundee            Scotland
# 31201  10007852.0  The University of Dundee            Scotland
# 31202  10007852.0  The University of Dundee            Scotland
# 31203  10007852.0  The University of Dundee            Scotland
# 31204  10007852.0  The University of Dundee            Scotland
# ...           ...                       ...                 ...
# 31635  10007852.0  The University of Dundee            Scotland
# 31636  10007852.0  The University of Dundee            Scotland
# 31637  10007852.0  The University of Dundee            Scotland
# 31638  10007852.0  The University of Dundee            Scotland
# 31639  10007852.0  The University of Dundee            Scotland
#
#       Mode of former study   Skill group  \
# 31200            Full-time  High skilled
# 31201            Full-time  High skilled
# 31202            Full-time  High skilled
# ...

# %%
institution_data_copy.loc[institution_data_copy["Number"].idxmax()]
# Out:
# UKPRN                                                NaN
# Provider name                                      Total
# Country of provider                                  All
# Mode of former study                                 All
# Skill group                                          All
# Work population marker    Paid employment is an activity
# Salary band                            £24,000 - £26,999
# Number                                             20920
# Name: 112684, dtype: object

# %%
#This ain't right yet!

institution_data_copy.loc[institution_data_copy
                           ["Provider name"] == "The University of Dundee"
                          ,"Number"].idxmax()
# Out:
# 31523

# %%
institution_data.sort_values("Number", ascending = False)
# Out:
#              UKPRN              Provider name Country of provider  \
# 112684         NaN                      Total                 All
# 112694         NaN                      Total                 All
# 112764         NaN                      Total                 All
# 112774         NaN                      Total                 All
# 112683         NaN                      Total                 All
# ...            ...                        ...                 ...
# 58254   10007820.0      Grŵp Llandrillo Menai                 All
# 58253   10007820.0      Grŵp Llandrillo Menai                 All
# 58252   10007820.0      Grŵp Llandrillo Menai                 All
# 58251   10007820.0      Grŵp Llandrillo Menai                 All
# 0       10008071.0  AA School of Architecture             England
#
#        Mode of former study   Skill group  \
# 112684                  All           All
# 112694                  All           All
# 112764            Full-time           All
# ...

# %%
import janitor as jntr

# %%
characteristic_data = characteristic_data.clean_names()

# %%
subject_data = subject_data.clean_names()

# %%
institution_data = institution_data.clean_names()

# %%
institution_data
# Out:
#              ukprn              provider_name country_of_provider  \
# 0       10008071.0  AA School of Architecture             England
# 1       10008071.0  AA School of Architecture             England
# 2       10008071.0  AA School of Architecture             England
# 3       10008071.0  AA School of Architecture             England
# 4       10008071.0  AA School of Architecture             England
# ...            ...                        ...                 ...
# 113875         NaN                      Total               Wales
# 113876         NaN                      Total               Wales
# 113877         NaN                      Total               Wales
# 113878         NaN                      Total               Wales
# 113879         NaN                      Total               Wales
#
#        mode_of_former_study     skill_group  \
# 0                 Full-time    High skilled
# 1                 Full-time    High skilled
# ...

# %%
institution_data["provider_name"].unique()
# Out:
# array(['AA School of Architecture', 'The University of Aberdeen',
#        'Abertay University', 'Aberystwyth University',
#        'Accrington and Rossendale College',
#        'Academy of Live and Recorded Arts', 'AECC University College',
#        'Anglia Ruskin University', 'Arden University',
#        'Arts Educational Schools', 'Askham Bryan College',
#        'Aston University', 'Aylesbury College', 'Bangor University',
#        'Barking and Dagenham College', 'Barnsley College',
#        'Barnet & Southgate College', 'Bath College',
#        'Bath Spa University', 'The University of Bath',
#        'University of Bedfordshire', "Queen's University Belfast",
#        'BIMM Limited', 'Birkbeck College',
#        'Birmingham Metropolitan College', 'Birmingham City University',
#        'The University of Birmingham', 'University College Birmingham',
#        'Bristol Baptist College', 'Bishop Burton College',
#        'Bishop Grosseteste University', 'Blackburn College',
# ...

# %%
rankings_data = pd.read_csv("hego_data/Complete_University_Guide_University_League_Table.csv", skiprows=4).clean_names()

# %%
rankings_data
# Out:
#       year  rank                 institution  entry_standards  \
# 0     2008     1                   Cambridge              530
# 1     2008     2                      Oxford              522
# 2     2008     3            Imperial College              453
# 3     2008     4  London School of Economics              471
# 4     2008     5                  St Andrews              458
# ...    ...   ...                         ...              ...
# 1702  2021   126             Wrexham Glyndŵr              100
# 1703  2021   127                      Bolton              110
# 1704  2021   128             Plymouth Marjon              111
# 1705  2021   129                     Suffolk              103
# 1706  2021   130                Ravensbourne              110
#
#       student_satisfaction  research_quality  research_intensity  \
# 0                    16.60              6.60                 NaN
# 1                    16.40              6.50                 NaN
# ...

# %% [markdown]
# Right, so really loose idea at this stage for the institutions data and rankings data. I'd like to see check if there is a clear correlation between the rankings and the graduate outcomes for the year in question (2017-18). There are probably a couple of options that we can take at this stage:
#
# 1. We pick a single year and use this as the basis of our comparison
# 2. We pick the years applicable to the majority of those studying at the institution (i.e. Undergraduate degree = 4 years) and take an average ranking.
# 3. We take an average of all of the years rankings available within the dataset.
#
# I'm going to start off by going for the first option here and then will probably move on to 2 and 3. More practice!

# %%
rankings_2017 = rankings_data.loc[rankings_data["year"] == 2017].copy()

# %% [markdown]
# Explanation of the above error = https://stackoverflow.com/questions/40659212/futurewarning-elementwise-comparison-failed-returning-scalar-but-in-the-futur

# %%
rankings_2017
# Out:
#       year  rank                              institution  entry_standards  \
# 1059  2017     1                                Cambridge              600
# 1060  2017     2                                   Oxford              574
# 1061  2017     3               London School of Economics              518
# 1062  2017     4                  Imperial College London              567
# 1063  2017     5                               St Andrews              520
# ...    ...   ...                                      ...              ...
# 1181  2017   123  University of Wales Trinity Saint David              284
# 1182  2017   124                          Plymouth Marjon              288
# 1183  2017   125                          Wrexham Glyndŵr              236
# 1184  2017   126                              East London              277
# 1185  2017   127                      London Metropolitan              247
#
#       student_satisfaction  research_quality  research_intensity  \
# ...

# %% [markdown]
# Right, so my main issues here is going to be the names of the different institutions. I need to work out if there is a way that I can match these or if they will need to be (gulp!) hard coded.

# %%
import difflib

# %%
difflib.get_close_matches
# Out:
# <function difflib.get_close_matches(word, possibilities, n=3, cutoff=0.6)>

# %% [markdown]
# Ok, i'm going to keep it simple at this stage and just match the rankings for 2017 with the institutions data.

# %%
just_2017_rankings = rankings_2017.loc[:,["rank", "institution"]].copy()

# %%
just_2017_rankings
# Out:
#       rank                              institution
# 1059     1                                Cambridge
# 1060     2                                   Oxford
# 1061     3               London School of Economics
# 1062     4                  Imperial College London
# 1063     5                               St Andrews
# ...    ...                                      ...
# 1181   123  University of Wales Trinity Saint David
# 1182   124                          Plymouth Marjon
# 1183   125                          Wrexham Glyndŵr
# 1184   126                              East London
# 1185   127                      London Metropolitan
#
# [127 rows x 2 columns]

# %%
institution_data_for_merge = institution_data.copy()

# %%
institution_data_for_merge
# Out:
#              ukprn              provider_name country_of_provider  \
# 0       10008071.0  AA School of Architecture             England
# 1       10008071.0  AA School of Architecture             England
# 2       10008071.0  AA School of Architecture             England
# 3       10008071.0  AA School of Architecture             England
# 4       10008071.0  AA School of Architecture             England
# ...            ...                        ...                 ...
# 113875         NaN                      Total               Wales
# 113876         NaN                      Total               Wales
# 113877         NaN                      Total               Wales
# 113878         NaN                      Total               Wales
# 113879         NaN                      Total               Wales
#
#        mode_of_former_study     skill_group  \
# 0                 Full-time    High skilled
# 1                 Full-time    High skilled
# ...

# %%
#institution_data_for_merge['provider_name'] = institution_data_for_merge['provider_name'].apply(lambda x: difflib.get_close_matches(x, just_2017_rankings['institution'])[0])
#institution_data_for_merge.merge(just_2017_rankings)

# %%
difflib.get_close_matches
# Out:
# <function difflib.get_close_matches(word, possibilities, n=3, cutoff=0.6)>

# %%
def fuzzy_merge(df1, df2, left_on, right_on, how='inner', cutoff=0.6):
    df_other= df2.copy()
    df_other[left_on] = [get_closest_match(x, df1[left_on], cutoff) 
                         for x in df_other[right_on]]
    return df1.merge(df_other, on=left_on, how=how)

def get_closest_match(x, other, cutoff):
    matches = difflib.get_close_matches(x, other, cutoff=cutoff)
    return matches[0] if matches else None

# %% [markdown]
# To clarify, the above is copied from the following source:
#
# https://stackoverflow.com/questions/13636848/is-it-possible-to-do-fuzzy-match-merge-with-python-pandas/60908516#60908516

# %% [markdown]
# Right, so after going through the resulst of the below merge, it looks like this really hasn't worked that well. I'm going to try and drop the word "University" from the "provider_name" column and see if this makes any difference.

# %%
institution_data_for_merge["provider_name"] = institution_data_for_merge["provider_name"].str.replace("University", '')

# %%
institution_outcomes_rankings_2017 = fuzzy_merge(institution_data_for_merge, just_2017_rankings, left_on='provider_name', right_on='institution').copy()

# %%
institution_outcomes_rankings_2017
# Out:
#             ukprn  provider_name country_of_provider mode_of_former_study  \
# 0      10007849.0       Abertay             Scotland            Full-time
# 1      10007849.0       Abertay             Scotland            Full-time
# 2      10007849.0       Abertay             Scotland            Full-time
# 3      10007849.0       Abertay             Scotland            Full-time
# 4      10007849.0       Abertay             Scotland            Full-time
# ...           ...            ...                 ...                  ...
# 51975  10007713.0  York St John              England            Part-time
# 51976  10007713.0  York St John              England            Part-time
# 51977  10007713.0  York St John              England            Part-time
# 51978  10007713.0  York St John              England            Part-time
# 51979  10007713.0  York St John              England            Part-time
#
#         skill_group                      work_population_marker  \
# ...

# %%
institution_outcomes_rankings_2017.sample(10)
# Out:
#             ukprn            provider_name country_of_provider  \
# 32705  10007832.0                  Newman                  All
# 22954  10007147.0         of Hertfordshire             England
# 35548  10007801.0              of Plymouth             England
# 42328  10006038.0        Southport College                 All
# 39541  10007782.0  St George's,  of London                 All
# 12060  10007848.0               of Chester                 All
# 17650  10007823.0               Edge Hill              England
# 42599  10006299.0           Staffordshire              England
# 2712   10007857.0                  Bangor                Wales
# 36900  10007775.0    Queen Mary  of London             England
#
#       mode_of_former_study     skill_group  \
# 32705                  All     Low skilled
# 22954            Full-time    High skilled
# 35548            Part-time    High skilled
# 42328            Full-time  Medium skilled
# 39541                  All     Low skilled
# ...

# %% [markdown]
# So this seems to have worked, but only to an extent. It looks like we've got some issues in terms of colleges being clasified as univiersities etc. Might have to do a quick manual check on this.

# %%
institution_outcomes_rankings_2017.isna().sum()
# Out:
# ukprn                     0
# provider_name             0
# country_of_provider       0
# mode_of_former_study      0
# skill_group               0
# work_population_marker    0
# salary_band               0
# number                    0
# rank                      0
# institution               0
# dtype: int64

# %%
problem_schools = institution_outcomes_rankings_2017.loc[institution_outcomes_rankings_2017["provider_name"].str.contains("College", case = False)].copy()

# %%
problem_schools
# Out:
#             ukprn          provider_name country_of_provider  \
# 24340  10003645.0  King's College London             England
# 24341  10003645.0  King's College London             England
# 24342  10003645.0  King's College London             England
# 24343  10003645.0  King's College London             England
# 24344  10003645.0  King's College London             England
# ...           ...                    ...                 ...
# 47775  10007784.0         College London             England
# 47776  10007784.0         College London             England
# 47777  10007784.0         College London             England
# 47778  10007784.0         College London             England
# 47779  10007784.0         College London             England
#
#       mode_of_former_study   skill_group  \
# 24340            Full-time  High skilled
# 24341            Full-time  High skilled
# 24342            Full-time  High skilled
# 24343            Full-time  High skilled
# ...

# %%
problem_schools["provider_name"].unique()
# Out:
# array(["King's College London", 'Southport College', ' College London'],
#       dtype=object)

# %%
problem_schools["institution"].unique()
# Out:
# array(["King's College London", 'Southampton Solent',
#        'Imperial College London', 'University College London'],
#       dtype=object)

# %%
rankings_2017["institution"].unique()
# Out:
# array(['Cambridge', 'Oxford', 'London School of Economics',
#        'Imperial College London', 'St Andrews', 'Durham', 'Loughborough',
#        'Warwick', 'Lancaster', 'University College London', 'Surrey',
#        'Bath', 'Exeter', 'East Anglia (UEA)', 'Birmingham', 'Leeds',
#        'Southampton', 'Sussex', 'Edinburgh', 'York',
#        "King's College London", 'Nottingham', 'Kent', 'Bristol',
#        'Manchester', 'Newcastle', 'Reading', 'Sheffield', 'Glasgow',
#        'Aston', 'Queen Mary, University of London', 'Leicester',
#        "Queen's, Belfast", 'Heriot-Watt', 'Cardiff', 'Dundee',
#        'Royal Holloway, University of London', 'Liverpool', 'Stirling',
#        'City, University of London', 'Essex', 'Aberdeen',
#        'SOAS University of London', "St George's, University of London",
#        'Swansea', 'Keele', 'Harper Adams', 'Strathclyde', 'Lincoln',
#        'Coventry', 'Goldsmiths, University of London',
# ...

# %%
kings_college = problem_schools.loc[problem_schools["institution"] == "King's College London"].copy()

# %%
kings_college["provider_name"].unique()
# Out:
# array(["King's College London"], dtype=object)

# %% [markdown]
# Ok, so after a wee bit of less than advanced wrangling it looks like we indeed have some colleges that are being misappropriated as universities. I'm going to drop the colleges and then rename the University College London mistakes.

# %%
institution_outcomes_rankings_2017["provider_name"] = institution_outcomes_rankings_2017["provider_name"].replace(["King's College London", "College London"], ["KC London", "UCL"])

# %%
institution_outcomes_rankings_2017.loc[institution_outcomes_rankings_2017.provider_name == "UCL", ["rank", "institution"]] = 10, "UCL"

# %%
institution_outcomes_rankings_2017.loc[institution_outcomes_rankings_2017["institution"] == "Dundee"]
# Out:
#             ukprn   provider_name country_of_provider mode_of_former_study  \
# 15920  10007852.0  The  of Dundee            Scotland            Full-time
# 15921  10007852.0  The  of Dundee            Scotland            Full-time
# 15922  10007852.0  The  of Dundee            Scotland            Full-time
# 15923  10007852.0  The  of Dundee            Scotland            Full-time
# 15924  10007852.0  The  of Dundee            Scotland            Full-time
# ...           ...             ...                 ...                  ...
# 16355  10007852.0  The  of Dundee            Scotland            Part-time
# 16356  10007852.0  The  of Dundee            Scotland            Part-time
# 16357  10007852.0  The  of Dundee            Scotland            Part-time
# 16358  10007852.0  The  of Dundee            Scotland            Part-time
# 16359  10007852.0  The  of Dundee            Scotland            Part-time
#
#         skill_group                      work_population_marker  \
# ...

# %%
institution_outcomes_rankings_2017["institution"].unique()
# Out:
# array(['Abertay', 'Aberystwyth', 'Anglia Ruskin', 'Aberdeen', 'Aston',
#        'Bangor', 'Bath', 'Bath Spa', 'Bedfordshire', "Queen's, Belfast",
#        'Birmingham', 'Birmingham City', 'Bishop Grosseteste', 'Bolton',
#        'Arts University Bournemouth', 'Bournemouth', 'Bradford',
#        'Brighton', 'Bristol', 'Brunel University London',
#        'Buckinghamshire New', 'Buckingham', 'Cambridge',
#        'Canterbury Christ Church', 'Cardiff', 'Cardiff Metropolitan',
#        'Central Lancashire', 'Chester', 'Chichester',
#        'City, University of London', 'Coventry',
#        'University for the Creative Arts', 'Northumbria', 'Cumbria',
#        'De Montfort', 'Derby', 'Dundee', 'Durham', 'East Anglia (UEA)',
#        'East London', 'Edge Hill', 'Edinburgh Napier', 'Edinburgh',
#        'Exeter', 'Falmouth', 'Glasgow Caledonian', 'Glasgow',
#        'Gloucestershire', 'Wrexham Glyndŵr', 'Greenwich', 'Harper Adams',
# ...

# %%
institution_outcomes_rankings_2017.describe(include = "all")
# Out:
#                ukprn provider_name country_of_provider mode_of_former_study  \
# count   5.198000e+04         51980               51980                51980
# unique           NaN           115                   5                    3
# top              NaN    of Cumbria                 All                  All
# freq             NaN           960               25990                19120
# mean    1.000651e+07           NaN                 NaN                  NaN
# std     3.737363e+03           NaN                 NaN                  NaN
# min     1.000029e+07           NaN                 NaN                  NaN
# 25%     1.000534e+07           NaN                 NaN                  NaN
# 50%     1.000716e+07           NaN                 NaN                  NaN
# 75%     1.000780e+07           NaN                 NaN                  NaN
# max     1.004081e+07           NaN                 NaN                  NaN
#
# ...

# %%
just_2017_rankings.describe(include = "all")
# Out:
#               rank institution
# count   127.000000         127
# unique         NaN         127
# top            NaN      Surrey
# freq           NaN           1
# mean     63.850394         NaN
# std      36.770433         NaN
# min       1.000000         NaN
# 25%      32.500000         NaN
# 50%      64.000000         NaN
# 75%      95.000000         NaN
# max     127.000000         NaN

# %% [markdown]
# Right, so this looks like a bit of a back to the drawing board moment. If our goal was to get all of the 127 institutions in the just_2017_rankings data joined up with corresponding data in institutions_data, it looks like we've only managed to do this for half of the insitutions and, even amongst these, there have been mistakes in the join (i.e. "Imperial College" for some UCLs).

# %% [markdown]
# So having modified the above and taken out "University" from the provider name, it looks like we've managed to improve the accuracy of the fuzzy merge. Still missing some institutions though. Let's see which ones they are:

# %%
university_groups = institution_outcomes_rankings_2017.groupby("provider_name")

university_groups_with_inst_labs = pd.DataFrame(university_groups.apply(lambda x: x ['institution'].unique()))

# %%
def print_full(x):
    pd.set_option('display.max_rows', len(x))
    print(x)
    pd.reset_option('display.max_rows')

# %%
print_full(university_groups_with_inst_labs)
# Out:
#                                                                                   0
# provider_name
#  College London                   [Imperial College London, University College L...
#  for the Creative Arts                           [University for the Creative Arts]
#  of Bedfordshire                                                     [Bedfordshire]
#  of Chester                                                               [Chester]
#  of Cumbria                                                  [Northumbria, Cumbria]
#  of Derby                                                                   [Derby]
#  of Durham                                                                 [Durham]
#  of Gloucestershire                                               [Gloucestershire]
#  of Hertfordshire                                                   [Hertfordshire]
#  of Nottingham                                                         [Nottingham]
# ...

# %% [markdown]
# Ok so we got close enough I think with that last attempt but I'm just going to hard code the remainder of schools that were misclassified:

# %%
institution_outcomes_rankings_2017 = institution_outcomes_rankings_2017[~institution_outcomes_rankings_2017['provider_name'].isin(['College London', 'of Cumbria', 'Arden', 'Bath Spa', 'Birmingham City', 'Liverpool Hope', 'London School of Theology', 'Southport College'])]

# %%
institution_outcomes_rankings_2017
# Out:
#             ukprn  provider_name country_of_provider mode_of_former_study  \
# 0      10007849.0       Abertay             Scotland            Full-time
# 1      10007849.0       Abertay             Scotland            Full-time
# 2      10007849.0       Abertay             Scotland            Full-time
# 3      10007849.0       Abertay             Scotland            Full-time
# 4      10007849.0       Abertay             Scotland            Full-time
# ...           ...            ...                 ...                  ...
# 51975  10007713.0  York St John              England            Part-time
# 51976  10007713.0  York St John              England            Part-time
# 51977  10007713.0  York St John              England            Part-time
# 51978  10007713.0  York St John              England            Part-time
# 51979  10007713.0  York St John              England            Part-time
#
#         skill_group                      work_population_marker  \
# ...

# %%
second_institution_merge_data = institution_data.copy()

# %%
second_institution_merge_data["provider_name"].unique()
# Out:
# array(['AA School of Architecture', 'The University of Aberdeen',
#        'Abertay University', 'Aberystwyth University',
#        'Accrington and Rossendale College',
#        'Academy of Live and Recorded Arts', 'AECC University College',
#        'Anglia Ruskin University', 'Arden University',
#        'Arts Educational Schools', 'Askham Bryan College',
#        'Aston University', 'Aylesbury College', 'Bangor University',
#        'Barking and Dagenham College', 'Barnsley College',
#        'Barnet & Southgate College', 'Bath College',
#        'Bath Spa University', 'The University of Bath',
#        'University of Bedfordshire', "Queen's University Belfast",
#        'BIMM Limited', 'Birkbeck College',
#        'Birmingham Metropolitan College', 'Birmingham City University',
#        'The University of Birmingham', 'University College Birmingham',
#        'Bristol Baptist College', 'Bishop Burton College',
#        'Bishop Grosseteste University', 'Blackburn College',
# ...

# %%
#second_institution_merge_data.loc[second_institution_merge_data['provider_name'].str.contains("Imperial")]

# %%
second_institution_merge_data['provider_name'] = second_institution_merge_data['provider_name'].replace({'Imperial College of Science, Technology and Medicine': 'Imperial College London'})

# %%
second_institution_merge_data = second_institution_merge_data[second_institution_merge_data["provider_name"].isin(['Imperial College London', 'University College London', 'University of Northumbria at Newcastle', 'University of Cumbria', 'Arden University', 'The University of Aberdeen', 'The University of Bath', 'Bath Spa University', 'The University of Liverpool', 'Liverpool Hope University', 'London School of Economics and Political Science', 'The University of Southampton', 'Solent University', 'The University of Birmingham', 'The University of York', 'The University of Kent', 'Royal Holloway and Bedford New College', 'The University of Essex', 'Goldsmiths College', 'The University of Hull', 'University of St Mark and St John'])]

# %%
#second_institution_merge_data.loc[second_institution_merge_data['provider_name'].str.contains("University College London")]

# %%
second_institution_merge_data
# Out:
#              ukprn               provider_name country_of_provider  \
# 160     10007783.0  The University of Aberdeen            Scotland
# 161     10007783.0  The University of Aberdeen            Scotland
# 162     10007783.0  The University of Aberdeen            Scotland
# 163     10007783.0  The University of Aberdeen            Scotland
# 164     10007783.0  The University of Aberdeen            Scotland
# ...            ...                         ...                 ...
# 112675  10007167.0      The University of York             England
# 112676  10007167.0      The University of York             England
# 112677  10007167.0      The University of York             England
# 112678  10007167.0      The University of York             England
# 112679  10007167.0      The University of York             England
#
#        mode_of_former_study   skill_group  \
# 160               Full-time  High skilled
# 161               Full-time  High skilled
# ...

# %%
conditions = [
    (second_institution_merge_data['provider_name'] == "Imperial College London"),
    (second_institution_merge_data['provider_name'] == "University College London"),
    (second_institution_merge_data['provider_name'] == "University of Northumbria at Newcastle"),
    (second_institution_merge_data['provider_name'] == "University of Cumbria"),
    (second_institution_merge_data['provider_name'] == "Arden University"),
    (second_institution_merge_data['provider_name'] == "The University of Aberdeen"),
    (second_institution_merge_data['provider_name'] == "The University of Bath"),
    (second_institution_merge_data['provider_name'] == "Bath Spa University"),
    (second_institution_merge_data['provider_name'] == "The University of Liverpool"),
    (second_institution_merge_data['provider_name'] == "Liverpool Hope University"),
    (second_institution_merge_data['provider_name'] == "London School of Economics and Political Science"),
    (second_institution_merge_data['provider_name'] == "The University of Southampton"),
    (second_institution_merge_data['provider_name'] == "Solent University"),
    (second_institution_merge_data['provider_name'] == "The University of Birmingham"),
    (second_institution_merge_data['provider_name'] == "The University of York"),
    (second_institution_merge_data['provider_name'] == "The University of Kent"),
    (second_institution_merge_data['provider_name'] == "Royal Holloway and Bedford New College"),
    (second_institution_merge_data['provider_name'] == "The University of Essex"),
    (second_institution_merge_data['provider_name'] == "Goldsmiths College"),
    (second_institution_merge_data['provider_name'] == "The University of Hull"),
    (second_institution_merge_data['provider_name'] == "University of St Mark and St John")
]

values = [4, 10, 59, 121,"NA",42,11,76,38,83,3,17,115,15, 20, 23, 37, 41, 51, 68, 124]

second_institution_merge_data['rank'] = np.select(conditions, values)

# %%
second_institution_merge_data.sample(10)
# Out:
#              ukprn                      provider_name country_of_provider  \
# 35267   10007791.0            The University of Essex             England
# 29202   10007842.0              University of Cumbria                 All
# 41344   10002718.0                 Goldsmiths College             England
# 29276   10007842.0              University of Cumbria                 All
# 96681   10037449.0  University of St Mark and St John                 All
# 560     10007783.0         The University of Aberdeen            Scotland
# 260     10007783.0         The University of Aberdeen                 All
# 57547   10006842.0        The University of Liverpool             England
# 35045   10007791.0            The University of Essex             England
# 103673  10007784.0          University College London             England
#
#        mode_of_former_study     skill_group  \
# 35267                   All    High skilled
# 29202             Full-time  Medium skilled
# ...

# %%
second_institution_merge_data["institution"] = second_institution_merge_data["provider_name"]

# %%
second_institution_merge_data
# Out:
#              ukprn               provider_name country_of_provider  \
# 160     10007783.0  The University of Aberdeen            Scotland
# 161     10007783.0  The University of Aberdeen            Scotland
# 162     10007783.0  The University of Aberdeen            Scotland
# 163     10007783.0  The University of Aberdeen            Scotland
# 164     10007783.0  The University of Aberdeen            Scotland
# ...            ...                         ...                 ...
# 112675  10007167.0      The University of York             England
# 112676  10007167.0      The University of York             England
# 112677  10007167.0      The University of York             England
# 112678  10007167.0      The University of York             England
# 112679  10007167.0      The University of York             England
#
#        mode_of_former_study   skill_group  \
# 160               Full-time  High skilled
# 161               Full-time  High skilled
# ...

# %%
all_institutions_out_n_ranks_2017 = pd.concat([institution_outcomes_rankings_2017, second_institution_merge_data])

# %%
all_institutions_out_n_ranks_2017
# Out:
#              ukprn           provider_name country_of_provider  \
# 0       10007849.0                Abertay             Scotland
# 1       10007849.0                Abertay             Scotland
# 2       10007849.0                Abertay             Scotland
# 3       10007849.0                Abertay             Scotland
# 4       10007849.0                Abertay             Scotland
# ...            ...                     ...                 ...
# 112675  10007167.0  The University of York             England
# 112676  10007167.0  The University of York             England
# 112677  10007167.0  The University of York             England
# 112678  10007167.0  The University of York             England
# 112679  10007167.0  The University of York             England
#
#        mode_of_former_study   skill_group  \
# 0                 Full-time  High skilled
# 1                 Full-time  High skilled
# 2                 Full-time  High skilled
# ...

# %%
all_institutions_out_n_ranks_2017.describe(include= 'all')
# Out:
#                ukprn provider_name country_of_provider mode_of_former_study  \
# count   6.034000e+04         60340               60340                60340
# unique           NaN           134                   5                    3
# top              NaN    of Cumbria                 All                  All
# freq             NaN           960               30170                22240
# mean    1.000665e+07           NaN                 NaN                  NaN
# std     4.442999e+03           NaN                 NaN                  NaN
# min     1.000029e+07           NaN                 NaN                  NaN
# 25%     1.000534e+07           NaN                 NaN                  NaN
# 50%     1.000716e+07           NaN                 NaN                  NaN
# 75%     1.000779e+07           NaN                 NaN                  NaN
# max     1.004081e+07           NaN                 NaN                  NaN
#
# ...

# %%
extra_institution_outcomes_rankings_2017 = all_institutions_out_n_ranks_2017.copy()

# %%
extra_institution_outcomes_rankings_2017
# Out:
#              ukprn           provider_name country_of_provider  \
# 0       10007849.0                Abertay             Scotland
# 1       10007849.0                Abertay             Scotland
# 2       10007849.0                Abertay             Scotland
# 3       10007849.0                Abertay             Scotland
# 4       10007849.0                Abertay             Scotland
# ...            ...                     ...                 ...
# 112675  10007167.0  The University of York             England
# 112676  10007167.0  The University of York             England
# 112677  10007167.0  The University of York             England
# 112678  10007167.0  The University of York             England
# 112679  10007167.0  The University of York             England
#
#        mode_of_former_study   skill_group  \
# 0                 Full-time  High skilled
# 1                 Full-time  High skilled
# 2                 Full-time  High skilled
# ...

# %% [markdown]
# Some universities still need to be dropped, Arden for example. Looks like we've got 126 provider names and 129 institution names so something has still gone amiss. I just need to find a way to check the two against eachother. Once I've done this, I can double check any gaps in the ranking by sorting the data and then I can get rid of the extra institution rows.

# %%
#extra_institution_outcomes_rankings_2017.sort_values(['provider_name', 'institution']).groupby('provider_name').head(10)

# %%
institution_check_data = extra_institution_outcomes_rankings_2017.groupby(['provider_name', 'institution']).size().reset_index().rename(columns={0:'count'})

# %%
pd.set_option('display.max_rows', 500)

# %%
institution_check_data
# Out:
#                                         provider_name  \
# 0                                      College London
# 1                                      College London
# 2                               for the Creative Arts
# 3                                     of Bedfordshire
# 4                                          of Chester
# 5                                          of Cumbria
# 6                                          of Cumbria
# 7                                            of Derby
# 8                                           of Durham
# 9                                  of Gloucestershire
# 10                                   of Hertfordshire
# 11                                      of Nottingham
# 12                                        of Plymouth
# 13                                     of South Wales
# 14                       of Wales Trinity Saint David
# 15                                       of Worcester
# ...

# %% [markdown]
# So looks like we'll need to get rid of:
#
#
# College London = Imperial College London
#
# Arden = Aberdeen
#
# Arden University = Arden University
#
# Bath Spa = Bath
#
# Birmingham City = Birmingham
#
# Liverpool Hope = Liverpool

# %%
#all_inst_minus_mistakes = all_institutions_out_n_ranks_2017.drop(all_institutions_out_n_ranks_2017[(all_institutions_out_n_ranks_2017["provider_name"] == "College London") & (all_institutions_out_n_ranks_2017["institution"] == "Imperial College London")].index) 
                                      #|[(all_institutions_out_n_ranks_2017["provider_name"] == "Arden") & (all_institutions_out_n_ranks_2017["institution"] == "Aberdeen")].index
                                      #|[(all_institutions_out_n_ranks_2017["provider_name"] == "Arden University") & (all_institutions_out_n_ranks_2017["institution"] == "Arden University")].index
                                      #|[(all_institutions_out_n_ranks_2017["provider_name"] == "Bath Spa") & (all_institutions_out_n_ranks_2017["institution"] == "Bath")].index
                                      #|[(all_institutions_out_n_ranks_2017["provider_name"] == "Birmingham City") & (all_institutions_out_n_ranks_2017["institution"] == "Birmingham")].index
                                      #|[(all_institutions_out_n_ranks_2017["provider_name"] == "Liverpool Hope") & (all_institutions_out_n_ranks_2017["institution"] == "Liverpool")].index)

# %%
all_inst_minus_mistakes = all_institutions_out_n_ranks_2017.loc[~((all_institutions_out_n_ranks_2017["provider_name"] == " College London") & (all_institutions_out_n_ranks_2017["institution"] == "Imperial College London")),:]
all_inst_minus_mistakes = all_inst_minus_mistakes.loc[~((all_inst_minus_mistakes["provider_name"] == "Arden ") & (all_inst_minus_mistakes["institution"] == "Aberdeen")),:]
all_inst_minus_mistakes = all_inst_minus_mistakes.loc[~((all_inst_minus_mistakes["provider_name"] == "Arden University") & (all_inst_minus_mistakes["institution"] == "Arden University")),:]
all_inst_minus_mistakes = all_inst_minus_mistakes.loc[~((all_inst_minus_mistakes["provider_name"] == "Bath Spa ") & (all_inst_minus_mistakes["institution"] == "Bath")),:]
all_inst_minus_mistakes = all_inst_minus_mistakes.loc[~((all_inst_minus_mistakes["provider_name"] == "Birmingham City ") & (all_inst_minus_mistakes["institution"] == "Birmingham")),:]
all_inst_minus_mistakes = all_inst_minus_mistakes.loc[~((all_inst_minus_mistakes["provider_name"] == "Liverpool Hope ") & (all_inst_minus_mistakes["institution"] == "Liverpool")),:]

# %%
#another_attempt_minus_mistakes = all_institutions_out_n_ranks_2017[(all_institutions_out_n_ranks_2017.provider_name != "College London") | all_institutions_out_n_ranks_2017.institution != "Imperial College London"]

# %%
#another_attempt_minus_mistakes = all_institutions_out_n_ranks_2017[(all_institutions_out_n_ranks_2017['provider_name']==" College London") & (all_institutions_out_n_ranks_2017['institution']=="Imperial College London")]

# %%
all_institutions_out_n_ranks_2017['provider_name'].dtypes
# Out:
# dtype('O')

# %%
all_inst_minus_mistakes
# Out:
#              ukprn           provider_name country_of_provider  \
# 0       10007849.0                Abertay             Scotland
# 1       10007849.0                Abertay             Scotland
# 2       10007849.0                Abertay             Scotland
# 3       10007849.0                Abertay             Scotland
# 4       10007849.0                Abertay             Scotland
# ...            ...                     ...                 ...
# 112675  10007167.0  The University of York             England
# 112676  10007167.0  The University of York             England
# 112677  10007167.0  The University of York             England
# 112678  10007167.0  The University of York             England
# 112679  10007167.0  The University of York             England
#
#        mode_of_former_study   skill_group  \
# 0                 Full-time  High skilled
# 1                 Full-time  High skilled
# 2                 Full-time  High skilled
# ...

# %%
list(all_institutions_out_n_ranks_2017.columns)
# Out:
# ['ukprn',
#  'provider_name',
#  'country_of_provider',
#  'mode_of_former_study',
#  'skill_group',
#  'work_population_marker',
#  'salary_band',
#  'number',
#  'rank',
#  'institution']

# %%
all_institutions_out_n_ranks_2017
# Out:
#              ukprn           provider_name country_of_provider  \
# 0       10007849.0                Abertay             Scotland
# 1       10007849.0                Abertay             Scotland
# 2       10007849.0                Abertay             Scotland
# 3       10007849.0                Abertay             Scotland
# 4       10007849.0                Abertay             Scotland
# ...            ...                     ...                 ...
# 112675  10007167.0  The University of York             England
# 112676  10007167.0  The University of York             England
# 112677  10007167.0  The University of York             England
# 112678  10007167.0  The University of York             England
# 112679  10007167.0  The University of York             England
#
#        mode_of_former_study   skill_group  \
# 0                 Full-time  High skilled
# 1                 Full-time  High skilled
# 2                 Full-time  High skilled
# ...

# %%
all_inst_minus_mistakes.describe(include= 'all')
# Out:
#                ukprn provider_name country_of_provider mode_of_former_study  \
# count   5.782000e+04         57820               57820                57820
# unique           NaN           132                   5                    3
# top              NaN    of Cumbria                 All                  All
# freq             NaN           960               28910                21280
# mean    1.000671e+07           NaN                 NaN                  NaN
# std     4.501818e+03           NaN                 NaN                  NaN
# min     1.000029e+07           NaN                 NaN                  NaN
# 25%     1.000534e+07           NaN                 NaN                  NaN
# 50%     1.000716e+07           NaN                 NaN                  NaN
# 75%     1.000779e+07           NaN                 NaN                  NaN
# max     1.004081e+07           NaN                 NaN                  NaN
#
# ...

# %%
minus_mistakes_check_data = all_inst_minus_mistakes.groupby(['provider_name', 'institution']).size().reset_index().rename(columns={0:'count'})

# %%
minus_mistakes_check_data
# Out:
#                                         provider_name  \
# 0                                      College London
# 1                               for the Creative Arts
# 2                                     of Bedfordshire
# 3                                          of Chester
# 4                                          of Cumbria
# 5                                          of Cumbria
# 6                                            of Derby
# 7                                           of Durham
# 8                                  of Gloucestershire
# 9                                    of Hertfordshire
# 10                                      of Nottingham
# 11                                        of Plymouth
# 12                                     of South Wales
# 13                       of Wales Trinity Saint David
# 14                                       of Worcester
# 15                                of the Arts, London
# ...

# %%
all_institutions_out_n_ranks_2017 = all_inst_minus_mistakes.copy()

# %%
# I can just write a quick function for this for practice.

#indexNames = all_institutions_out_n_ranks_2017[(all_institutions_out_n_ranks_2017['provider_name'] == 'Liverpool Hope') & (all_institutions_out_n_ranks_2017['institution'] == 'Liverpool')].index

#all_institutions_out_n_ranks_2017.drop(indexNames, inplace= True)

# %%
#Going to come back to this I think.
#def remove_institution(df, provider, institution):
    
#    institutions_to_go = df[
#    (df['provider_name'] == provider) 
#    & b
#    (df['institution'] == institution)
#    ].index
#    return df

#df.drop(institutions_to_go, inplace= True)

# %%
all_institutions_out_n_ranks_2017.describe(include= 'all')
# Out:
#                ukprn provider_name country_of_provider mode_of_former_study  \
# count   5.782000e+04         57820               57820                57820
# unique           NaN           132                   5                    3
# top              NaN    of Cumbria                 All                  All
# freq             NaN           960               28910                21280
# mean    1.000671e+07           NaN                 NaN                  NaN
# std     4.501818e+03           NaN                 NaN                  NaN
# min     1.000029e+07           NaN                 NaN                  NaN
# 25%     1.000534e+07           NaN                 NaN                  NaN
# 50%     1.000716e+07           NaN                 NaN                  NaN
# 75%     1.000779e+07           NaN                 NaN                  NaN
# max     1.004081e+07           NaN                 NaN                  NaN
#
# ...

# %% [markdown]
# Looks like our data is finally clean. We've got 123 institutions matched with their ratings. Now to arrange the data and check to see if we have accurate lists.

# %%
all_institutions_out_n_ranks_2017["rank"] = pd.to_numeric(all_institutions_out_n_ranks_2017["rank"])

# %%
all_institutions_out_n_ranks_2017.sort_values("rank")
# Out:
#             ukprn         provider_name country_of_provider  \
# 9838   10007788.0     The  of Cambridge                 All
# 9938   10007788.0     The  of Cambridge             England
# 9937   10007788.0     The  of Cambridge             England
# 9936   10007788.0     The  of Cambridge             England
# 9935   10007788.0     The  of Cambridge             England
# ...           ...                   ...                 ...
# 29512  10004048.0  London Metropolitan              England
# 29511  10004048.0  London Metropolitan              England
# 29510  10004048.0  London Metropolitan              England
# 29534  10004048.0  London Metropolitan              England
# 29578  10004048.0  London Metropolitan                  All
#
#       mode_of_former_study     skill_group  \
# 9838             Full-time  Medium skilled
# 9938                   All     Low skilled
# 9937                   All     Low skilled
# 9936                   All     Low skilled
# ...

# %%
all_institutions_out_n_ranks_2017 = all_institutions_out_n_ranks_2017.loc[~(all_institutions_out_n_ranks_2017["institution"].isin(["Southampton", "Northumbria", "Bath Spa", "Liverpool Hope", "Cumbria"]))]

# %%
check_gaps = all_institutions_out_n_ranks_2017.groupby(['rank', 'institution']).size().reset_index().rename(columns={0:'count'})

# %%
check_gaps
# Out:
#      rank                                       institution  count
# 0       1                                         Cambridge    320
# 1       2                                            Oxford    400
# 2       3  London School of Economics and Political Science    320
# 3       4                           Imperial College London    320
# 4       5                                        St Andrews    440
# 5       6                                            Durham    400
# 6       7                                      Loughborough    440
# 7       8                                           Warwick    440
# 8       9                                         Lancaster    320
# 9      10                         University College London    800
# 10     11                                            Surrey    440
# 11     11                            The University of Bath    400
# 12     13                                            Exeter    440
# ...

# %%
all_institutions_out_n_ranks_2017.duplicated().any()
# Out:
# False
